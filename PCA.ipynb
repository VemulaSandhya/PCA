# %%
import pandas as pd 
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale

# %%
uni = pd.read_csv("C:/Users/Vikas Srivastava/Desktop/ExcelR/Latest DS Material/Day 19 - PCA and tSNE/PCA/PCA.csv")
#print(uni.describe())
uni.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
uni
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
# Considering only numerical data
universities = uni.Univ 
uni = uni.iloc[:,1:]
display(uni.head())
# Converting into numpy array
UNI = uni.values
UNI
# Out:
#     SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0  1310     89      22       13     22704        94
# 1  1415    100      25        6     63575        81
# 2  1260     62      59        9     25026        72
# 3  1310     76      24       12     31510        88
# 4  1280     83      33       13     21864        90
# array([[ 1310,    89,    22,    13, 22704,    94],
#        [ 1415,   100,    25,     6, 63575,    81],
#        [ 1260,    62,    59,     9, 25026,    72],
#        [ 1310,    76,    24,    12, 31510,    88],
#        [ 1280,    83,    33,    13, 21864,    90],
#        [ 1340,    89,    23,    10, 32162,    95],
#        [ 1315,    90,    30,    12, 31585,    95],
#        [ 1255,    74,    24,    12, 20126,    92],
#        [ 1400,    91,    14,    11, 39525,    97],
#        [ 1305,    75,    44,     7, 58691,    87],
#        [ 1380,    94,    30,    10, 34870,    91],
#        [ 1260,    85,    39,    11, 28052,    89],
# ...

# %%
#uni.describe()

# %%
# Normalizing the numerical data 
uni_normal = scale(UNI)

# %%
uni_normal
# Out:
# array([[ 0.41028362,  0.6575195 , -0.88986682,  0.07026045, -0.33141256,
#          0.82030265],
#        [ 1.39925928,  1.23521235, -0.73465749, -1.68625071,  2.56038138,
#         -0.64452351],
#        [-0.06065717, -0.76045386,  1.02438157, -0.93346022, -0.16712136,
#         -1.65863393],
#        [ 0.41028362, -0.02520842, -0.78639393, -0.18066972,  0.29164871,
#          0.14422904],
#        [ 0.12771914,  0.34241431, -0.32076595,  0.07026045, -0.39084607,
#          0.36958691],
#        [ 0.69284809,  0.6575195 , -0.83813038, -0.68253005,  0.33778044,
#          0.93298158],
#        [ 0.4573777 ,  0.71003703, -0.47597528, -0.18066972,  0.29695528,
#          0.93298158],
#        [-0.10775125, -0.13024348, -0.78639393, -0.18066972, -0.51381683,
#          0.59494478],
#        [ 1.25797704,  0.76255456, -1.30375836, -0.43159988,  0.85874344,
#          1.15833946],
#        [ 0.36318954, -0.07772595,  0.24833493, -1.43532055,  2.21481798,
#          0.0315501 ],
# ...

# %%
pca = PCA()
pca_values = pca.fit_transform(uni_normal)

# %%
pc = pd.DataFrame(pca_values)
pc
# Out:
#            0         1         2         3         4         5
# 0  -1.009874 -1.064310  0.081066  0.056951 -0.128754 -0.034650
# 1  -2.822238  2.259045  0.836829  0.143845 -0.125962 -0.180703
# 2   1.112466  1.631209 -0.266787  1.075075 -0.191814  0.345679
# 3  -0.741741 -0.042187  0.060501 -0.157208 -0.577611  0.109163
# 4  -0.311912 -0.635244  0.010241  0.171364  0.012726 -0.016921
# 5  -1.696691 -0.344363 -0.253408  0.012564 -0.052661 -0.027166
# 6  -1.246821 -0.490984 -0.032094 -0.205644  0.293505 -0.078012
# 7  -0.338750 -0.785169 -0.493585  0.039856 -0.544979 -0.155372
# 8  -2.374150 -0.386539  0.116098 -0.453366 -0.230108  0.266984
# 9  -1.403277  2.119515 -0.442827 -0.632543  0.230054 -0.235615
# 10 -1.726103  0.088237  0.170404  0.260902  0.233318  0.238968
# 11 -0.450857 -0.011133 -0.175746  0.236166  0.263251 -0.314844
# 12  0.040238 -1.009204 -0.496517  0.229299  0.448032  0.004939
# 13  3.233730 -0.374580 -0.495373 -0.521238 -0.639295 -0.090048
# ...

# %%
# pca.components_

# %%
pca.components_
# Out:
# array([[-0.45774863, -0.42714437,  0.42430805,  0.39064831, -0.36252316,
#         -0.37940403],
#        [ 0.03968044, -0.19993153,  0.32089297, -0.43256441,  0.6344864 ,
#         -0.51555367],
#        [ 0.1870388 ,  0.49780855, -0.15627899,  0.60608085,  0.20474114,
#         -0.53247261],
#        [ 0.13124033,  0.37489567,  0.0612872 , -0.50739095, -0.62340055,
#         -0.43863341],
#        [ 0.02064583,  0.4820162 ,  0.8010936 ,  0.07682369,  0.07254775,
#          0.33810965],
#        [ 0.8580547 , -0.39607492,  0.21693361,  0.1720479 , -0.17376309,
#         -0.00353754]])

# %%
### before applying pca ....input data

# SAT	Top10	Accept	SFRatio	Expenses	GradRate
# [ 0.41028362,  0.6575195 , -0.88986682,  0.07026045, -0.33141256,
#          0.82030265]

# %%
# ### output after applying pca... 1st row
# pc1---------pc2----------pc3--------pc4----------pc5----------pc6
# -1.009874	-1.064310	0.081066	0.056951	-0.128754	-0.034650

# %%
pc1 = (-0.45774863*0.41028362) + (-0.42714437*0.6575195) + (0.42430805*-0.88986682) + (0.39064831*0.07026045) + (-0.36252316*-0.33141256) + (-0.37940403*0.82030265)
pc1
# Out:
# -1.0098744493730072

# %%
pc6 = (0.8580547*0.41028362) + (-0.39607492*0.6575195) + (0.21693361*-0.88986682) + (0.1720479*0.07026045) + (-0.17376309*-0.33141256) + (-0.00353754*0.82030265)
pc6
# Out:
# -0.034649636639261815

# %%
# The amount of variance that each PCA explains is 
var = pca.explained_variance_ratio_
var
# Out:
# array([0.76868084, 0.13113602, 0.04776031, 0.02729668, 0.0207177 ,
#        0.00440844])

# %%
# Cumulative variance 
var1 = np.cumsum(np.round(var,decimals = 4)*100)
var1
# Out:
# array([ 76.87,  89.98,  94.76,  97.49,  99.56, 100.  ])

# %%
# Variance plot for PCA components obtained 
plt.plot(var1,color="red")

# %%
finalDf = pd.concat([pd.DataFrame(pca_values[:,0:2],columns=['pc1','pc2']), universities], axis = 1)

# %%
finalDf
# Out:
#          pc1       pc2          Univ
# 0  -1.009874 -1.064310         Brown
# 1  -2.822238  2.259045       CalTech
# 2   1.112466  1.631209           CMU
# 3  -0.741741 -0.042187      Columbia
# 4  -0.311912 -0.635244       Cornell
# 5  -1.696691 -0.344363     Dartmouth
# 6  -1.246821 -0.490984          Duke
# 7  -0.338750 -0.785169    Georgetown
# 8  -2.374150 -0.386539       Harvard
# 9  -1.403277  2.119515  JohnsHopkins
# 10 -1.726103  0.088237           MIT
# 11 -0.450857 -0.011133  Northwestern
# 12  0.040238 -1.009204     NotreDame
# 13  3.233730 -0.374580     PennState
# 14 -2.236265 -0.371793     Princeton
# 15  5.172992  0.779915        Purdue
# 16 -1.699644 -0.305597      Stanford
# 17  4.578146 -0.347591      TexasA&M
# 18  0.822603 -0.698906    UCBerkeley
# 19 -0.097762  0.650446      UChicago
# 20  1.963183 -0.224768     UMichigan
# 21 -0.542289 -0.079589         UPenn
# 22  0.532221 -1.017167           UVA
# 23  3.548697  0.778462    UWisconsin
# ...

# %%
finalDf1 = finalDf.drop(('Univ'),axis=1)
finalDf1
# Out:
#          pc1       pc2
# 0  -1.009874 -1.064310
# 1  -2.822238  2.259045
# 2   1.112466  1.631209
# 3  -0.741741 -0.042187
# 4  -0.311912 -0.635244
# 5  -1.696691 -0.344363
# 6  -1.246821 -0.490984
# 7  -0.338750 -0.785169
# 8  -2.374150 -0.386539
# 9  -1.403277  2.119515
# 10 -1.726103  0.088237
# 11 -0.450857 -0.011133
# 12  0.040238 -1.009204
# 13  3.233730 -0.374580
# 14 -2.236265 -0.371793
# 15  5.172992  0.779915
# 16 -1.699644 -0.305597
# 17  4.578146 -0.347591
# 18  0.822603 -0.698906
# 19 -0.097762  0.650446
# 20  1.963183 -0.224768
# 21 -0.542289 -0.079589
# 22  0.532221 -1.017167
# 23  3.548697  0.778462
# 24 -2.305900 -0.117704

# %%
# import seaborn as sns
# sns.scatterplot(data=finalDf,x='pc1',y='pc2',hue='Univ')
